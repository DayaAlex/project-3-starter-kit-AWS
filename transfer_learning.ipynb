# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for Landmark Classification
#
#
# ### Transfer learning
#
# In the previous notebook we have trained our own CNN and we got a certain performance. Let's see how hard it is to match that performance with transfer learning.
#
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 0: Setting up
#
# The following cells make sure that your environment is setup correctly and check that your GPU is available and ready to go. You have to execute them every time you restart your notebook.

# %%
# Install requirements
# !pip install -r requirements.txt | grep -v "already satisfied"
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com

# %%
from src.helpers import setup_env

# If running locally, this will download dataset (make sure you have at 
# least 2 Gb of space on your hard drive)
setup_env()
# Out:
# hello
# GPU available
# tensor([1.], device='mps:0')
# Dataset already downloaded. If you need to re-download, please delete the directory landmark_images
# Reusing cached mean and std

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 1: Create transfer learning architecture
#
# Open the file `src/transfer.py` and complete the `get_model_transfer_learning` function. When you are done, execute this test:

# %%
# !pytest -vv src/transfer.py
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.19, pytest-8.1.1, pluggy-1.4.0 -- /Users/dalex/miniforge3/envs/aws_ml_funda/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/dalex/Desktop/aws_schol_2/project-3-starter-kit-AWS
# plugins: mypy-0.10.3, anyio-4.4.0
# collected 1 item
#
# src/transfer.py::test_get_model_transfer_learning PASSED                 [100%]
#
# =============================== warnings summary ===============================
# src/transfer.py::test_get_model_transfer_learning
#   /Users/dalex/miniforge3/envs/aws_ml_funda/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#     warnings.warn(
#
# src/transfer.py::test_get_model_transfer_learning
#   /Users/dalex/miniforge3/envs/aws_ml_funda/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#     warnings.warn(msg)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================== 1 passed, 2 warnings in 16.42s ========================

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 2: Train, validation and test
#
# Let's train our transfer learning model! Let's start defining the hyperparameters:

# %%
batch_size = 64  # size of the minibatch for stochastic gradient descent (or Adam)
valid_size = 0.2  # fraction of the training data to reserve for validation
num_epochs = 10  # number of epochs for training
num_classes = 50  # number of classes. Do not change this
learning_rate = 0.001  # Learning rate for SGD (or Adam)
opt = 'adam'      # optimizer. 'sgd' or 'adam'
weight_decay = 0.0 # regularization. Increase this to combat overfitting

# %%
from src.data import get_data_loaders
from src.optimization import get_optimizer, get_loss
from src.train import optimize
from src.transfer import get_model_transfer_learning
import torchinfo

# Get a model using get_model_transfer_learning. Use one of the names reported here:
# https://pytorch.org/vision/0.10/models.html
# For example, if you want to load ResNet 18, use "resnet18"
# NOTE: use the hyperparameters defined in the previous cell, do NOT copy/paste the
# values
model_transfer = get_model_transfer_learning()

# train the model
data_loaders = get_data_loaders(batch_size=batch_size)
optimizer = get_optimizer(
    model_transfer,
    learning_rate=learning_rate,
    optimizer=opt,
    weight_decay=weight_decay,
)
loss = get_loss()

optimize(
    data_loaders,
    model_transfer,
    optimizer,
    loss,
    n_epochs=num_epochs,
    save_path="checkpoints/model_transfer.pt",
    interactive_tracking=True
)
# Out:
# Epoch: 15 	Training Loss: 1.059216 	Validation Loss: 1.182013 	Validation Accuracy: 69.60%
# Training: 100%|█████████████████████████████████| 63/63 [00:26<00:00,  2.36it/s]
# Validating: 100%|███████████████████████████████| 16/16 [00:04<00:00,  3.20it/s]
# New minimum validation loss: 1.164096. Saving model ...
# Testing:  20%|███████                            | 4/20 [00:03<00:13,  1.21it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 25
#      17 optimizer = get_optimizer(
#      18     model_transfer,
#      19     learning_rate=learning_rate,
#      20     optimizer=opt,
#      21     weight_decay=weight_decay,
#      22 )
#      23 loss = get_loss()
# ---> 25 optimize(
#      26     data_loaders,
#      27     model_transfer,
#      28     optimizer,
#      29     loss,
#      30     n_epochs=num_epochs,
#      31     save_path="checkpoints/model_transfer.pt",
#      32     interactive_tracking=True
#      33 )
#
# File ~/Desktop/aws_schol_2/project-3-starter-kit-AWS/src/train.py:143, in optimize(data_loaders, model, optimizer, loss, n_epochs, save_path, interactive_tracking)
#     141 # Test the model and log the test result.
#     142 if interactive_tracking and (valid_loss_min_count % 3 == 0):
# --> 143     _, logs["Test Accuracy"] = one_epoch_test(data_loaders['test'], model, loss)
#     145 # Save the weights to save_path
#     146 torch.save(model.state_dict(), save_path)
#
# File ~/Desktop/aws_schol_2/project-3-starter-kit-AWS/src/train.py:199, in one_epoch_test(test_dataloader, model, loss)
#     197 loss_value  = loss(logits, target)
#     198 # update average test loss
# --> 199 test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss_value.data.item() - test_loss))
#     201 # convert logits to predicted class
#     202 # HINT: the predicted class is the index of the max of the logits
#     203 pred  = torch.argmax(logits, dim=1)
#
# KeyboardInterrupt:

# %%
torchinfo.summary(model_transfer, input_size=(1,3, 224, 224), verbose=2)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNet                                   [1, 50]                   --
# ├─Conv2d: 1-1                            [1, 64, 112, 112]         (9,408)
# │    └─weight                                                      └─9,408
# ├─BatchNorm2d: 1-2                       [1, 64, 112, 112]         (128)
# │    └─weight                                                      ├─64
# │    └─bias                                                        └─64
# ├─ReLU: 1-3                              [1, 64, 112, 112]         --
# ├─MaxPool2d: 1-4                         [1, 64, 56, 56]           --
# ├─Sequential: 1-5                        [1, 64, 56, 56]           --
# │    └─0.conv1.weight                                              ├─36,864
# │    └─0.bn1.weight                                                ├─64
# │    └─0.bn1.bias                                                  ├─64
# │    └─0.conv2.weight                                              ├─36,864
# │    └─0.bn2.weight                                                ├─64
# │    └─0.bn2.bias                                                  ├─64
# │    └─1.conv1.weight                                              ├─36,864
# │    └─1.bn1.weight                                                ├─64
# │    └─1.bn1.bias                                                  ├─64
# │    └─1.conv2.weight                                              ├─36,864
# │    └─1.bn2.weight                                                ├─64
# │    └─1.bn2.bias                                                  └─64
# │    └─BasicBlock: 2-1                   [1, 64, 56, 56]           --
# │    │    └─conv1.weight                                           ├─36,864
# │    │    └─bn1.weight                                             ├─64
# │    │    └─bn1.bias                                               ├─64
# │    │    └─conv2.weight                                           ├─36,864
# │    │    └─bn2.weight                                             ├─64
# │    │    └─bn2.bias                                               └─64
# │    │    └─Conv2d: 3-1                  [1, 64, 56, 56]           (36,864)
# │    │    │    └─weight                                            └─36,864
# │    │    └─BatchNorm2d: 3-2             [1, 64, 56, 56]           (128)
# │    │    │    └─weight                                            ├─64
# │    │    │    └─bias                                              └─64
# │    │    └─ReLU: 3-3                    [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-4                  [1, 64, 56, 56]           (36,864)
# │    │    │    └─weight                                            └─36,864
# │    │    └─BatchNorm2d: 3-5             [1, 64, 56, 56]           (128)
# │    │    │    └─weight                                            ├─64
# │    │    │    └─bias                                              └─64
# │    │    └─ReLU: 3-6                    [1, 64, 56, 56]           --
# │    └─BasicBlock: 2-2                   [1, 64, 56, 56]           --
# │    │    └─conv1.weight                                           ├─36,864
# │    │    └─bn1.weight                                             ├─64
# │    │    └─bn1.bias                                               ├─64
# │    │    └─conv2.weight                                           ├─36,864
# │    │    └─bn2.weight                                             ├─64
# │    │    └─bn2.bias                                               └─64
# │    │    └─Conv2d: 3-7                  [1, 64, 56, 56]           (36,864)
# │    │    │    └─weight                                            └─36,864
# │    │    └─BatchNorm2d: 3-8             [1, 64, 56, 56]           (128)
# │    │    │    └─weight                                            ├─64
# │    │    │    └─bias                                              └─64
# │    │    └─ReLU: 3-9                    [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-10                 [1, 64, 56, 56]           (36,864)
# │    │    │    └─weight                                            └─36,864
# │    │    └─BatchNorm2d: 3-11            [1, 64, 56, 56]           (128)
# │    │    │    └─weight                                            ├─64
# │    │    │    └─bias                                              └─64
# │    │    └─ReLU: 3-12                   [1, 64, 56, 56]           --
# ├─Sequential: 1-6                        [1, 128, 28, 28]          --
# │    └─0.conv1.weight                                              ├─73,728
# │    └─0.bn1.weight                                                ├─128
# │    └─0.bn1.bias                                                  ├─128
# │    └─0.conv2.weight                                              ├─147,456
# │    └─0.bn2.weight                                                ├─128
# │    └─0.bn2.bias                                                  ├─128
# │    └─0.downsample.0.weight                                       ├─8,192
# │    └─0.downsample.1.weight                                       ├─128
# │    └─0.downsample.1.bias                                         ├─128
# │    └─1.conv1.weight                                              ├─147,456
# │    └─1.bn1.weight                                                ├─128
# │    └─1.bn1.bias                                                  ├─128
# │    └─1.conv2.weight                                              ├─147,456
# │    └─1.bn2.weight                                                ├─128
# │    └─1.bn2.bias                                                  └─128
# │    └─BasicBlock: 2-3                   [1, 128, 28, 28]          --
# │    │    └─conv1.weight                                           ├─73,728
# │    │    └─bn1.weight                                             ├─128
# │    │    └─bn1.bias                                               ├─128
# │    │    └─conv2.weight                                           ├─147,456
# │    │    └─bn2.weight                                             ├─128
# │    │    └─bn2.bias                                               ├─128
# │    │    └─downsample.0.weight                                    ├─8,192
# │    │    └─downsample.1.weight                                    ├─128
# │    │    └─downsample.1.bias                                      └─128
# │    │    └─Conv2d: 3-13                 [1, 128, 28, 28]          (73,728)
# │    │    │    └─weight                                            └─73,728
# │    │    └─BatchNorm2d: 3-14            [1, 128, 28, 28]          (256)
# │    │    │    └─weight                                            ├─128
# │    │    │    └─bias                                              └─128
# │    │    └─ReLU: 3-15                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-16                 [1, 128, 28, 28]          (147,456)
# │    │    │    └─weight                                            └─147,456
# │    │    └─BatchNorm2d: 3-17            [1, 128, 28, 28]          (256)
# │    │    │    └─weight                                            ├─128
# │    │    │    └─bias                                              └─128
# │    │    └─Sequential: 3-18             [1, 128, 28, 28]          (8,448)
# │    │    │    └─0.weight                                          ├─8,192
# │    │    │    └─1.weight                                          ├─128
# │    │    │    └─1.bias                                            └─128
# │    │    └─ReLU: 3-19                   [1, 128, 28, 28]          --
# │    └─BasicBlock: 2-4                   [1, 128, 28, 28]          --
# │    │    └─conv1.weight                                           ├─147,456
# │    │    └─bn1.weight                                             ├─128
# │    │    └─bn1.bias                                               ├─128
# │    │    └─conv2.weight                                           ├─147,456
# │    │    └─bn2.weight                                             ├─128
# │    │    └─bn2.bias                                               └─128
# │    │    └─Conv2d: 3-20                 [1, 128, 28, 28]          (147,456)
# │    │    │    └─weight                                            └─147,456
# │    │    └─BatchNorm2d: 3-21            [1, 128, 28, 28]          (256)
# │    │    │    └─weight                                            ├─128
# │    │    │    └─bias                                              └─128
# │    │    └─ReLU: 3-22                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-23                 [1, 128, 28, 28]          (147,456)
# │    │    │    └─weight                                            └─147,456
# │    │    └─BatchNorm2d: 3-24            [1, 128, 28, 28]          (256)
# │    │    │    └─weight                                            ├─128
# │    │    │    └─bias                                              └─128
# │    │    └─ReLU: 3-25                   [1, 128, 28, 28]          --
# ├─Sequential: 1-7                        [1, 256, 14, 14]          --
# │    └─0.conv1.weight                                              ├─294,912
# │    └─0.bn1.weight                                                ├─256
# │    └─0.bn1.bias                                                  ├─256
# │    └─0.conv2.weight                                              ├─589,824
# │    └─0.bn2.weight                                                ├─256
# │    └─0.bn2.bias                                                  ├─256
# │    └─0.downsample.0.weight                                       ├─32,768
# │    └─0.downsample.1.weight                                       ├─256
# │    └─0.downsample.1.bias                                         ├─256
# │    └─1.conv1.weight                                              ├─589,824
# │    └─1.bn1.weight                                                ├─256
# │    └─1.bn1.bias                                                  ├─256
# │    └─1.conv2.weight                                              ├─589,824
# │    └─1.bn2.weight                                                ├─256
# │    └─1.bn2.bias                                                  └─256
# │    └─BasicBlock: 2-5                   [1, 256, 14, 14]          --
# │    │    └─conv1.weight                                           ├─294,912
# │    │    └─bn1.weight                                             ├─256
# │    │    └─bn1.bias                                               ├─256
# │    │    └─conv2.weight                                           ├─589,824
# │    │    └─bn2.weight                                             ├─256
# │    │    └─bn2.bias                                               ├─256
# │    │    └─downsample.0.weight                                    ├─32,768
# │    │    └─downsample.1.weight                                    ├─256
# │    │    └─downsample.1.bias                                      └─256
# │    │    └─Conv2d: 3-26                 [1, 256, 14, 14]          (294,912)
# │    │    │    └─weight                                            └─294,912
# │    │    └─BatchNorm2d: 3-27            [1, 256, 14, 14]          (512)
# │    │    │    └─weight                                            ├─256
# │    │    │    └─bias                                              └─256
# │    │    └─ReLU: 3-28                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-29                 [1, 256, 14, 14]          (589,824)
# │    │    │    └─weight                                            └─589,824
# │    │    └─BatchNorm2d: 3-30            [1, 256, 14, 14]          (512)
# │    │    │    └─weight                                            ├─256
# │    │    │    └─bias                                              └─256
# │    │    └─Sequential: 3-31             [1, 256, 14, 14]          (33,280)
# │    │    │    └─0.weight                                          ├─32,768
# │    │    │    └─1.weight                                          ├─256
# │    │    │    └─1.bias                                            └─256
# │    │    └─ReLU: 3-32                   [1, 256, 14, 14]          --
# │    └─BasicBlock: 2-6                   [1, 256, 14, 14]          --
# │    │    └─conv1.weight                                           ├─589,824
# │    │    └─bn1.weight                                             ├─256
# │    │    └─bn1.bias                                               ├─256
# │    │    └─conv2.weight                                           ├─589,824
# │    │    └─bn2.weight                                             ├─256
# │    │    └─bn2.bias                                               └─256
# │    │    └─Conv2d: 3-33                 [1, 256, 14, 14]          (589,824)
# │    │    │    └─weight                                            └─589,824
# │    │    └─BatchNorm2d: 3-34            [1, 256, 14, 14]          (512)
# │    │    │    └─weight                                            ├─256
# │    │    │    └─bias                                              └─256
# │    │    └─ReLU: 3-35                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-36                 [1, 256, 14, 14]          (589,824)
# │    │    │    └─weight                                            └─589,824
# │    │    └─BatchNorm2d: 3-37            [1, 256, 14, 14]          (512)
# │    │    │    └─weight                                            ├─256
# │    │    │    └─bias                                              └─256
# │    │    └─ReLU: 3-38                   [1, 256, 14, 14]          --
# ├─Sequential: 1-8                        [1, 512, 7, 7]            --
# │    └─0.conv1.weight                                              ├─1,179,648
# │    └─0.bn1.weight                                                ├─512
# │    └─0.bn1.bias                                                  ├─512
# │    └─0.conv2.weight                                              ├─2,359,296
# │    └─0.bn2.weight                                                ├─512
# │    └─0.bn2.bias                                                  ├─512
# │    └─0.downsample.0.weight                                       ├─131,072
# │    └─0.downsample.1.weight                                       ├─512
# │    └─0.downsample.1.bias                                         ├─512
# │    └─1.conv1.weight                                              ├─2,359,296
# │    └─1.bn1.weight                                                ├─512
# │    └─1.bn1.bias                                                  ├─512
# │    └─1.conv2.weight                                              ├─2,359,296
# │    └─1.bn2.weight                                                ├─512
# │    └─1.bn2.bias                                                  └─512
# │    └─BasicBlock: 2-7                   [1, 512, 7, 7]            --
# │    │    └─conv1.weight                                           ├─1,179,648
# │    │    └─bn1.weight                                             ├─512
# │    │    └─bn1.bias                                               ├─512
# │    │    └─conv2.weight                                           ├─2,359,296
# │    │    └─bn2.weight                                             ├─512
# │    │    └─bn2.bias                                               ├─512
# │    │    └─downsample.0.weight                                    ├─131,072
# │    │    └─downsample.1.weight                                    ├─512
# │    │    └─downsample.1.bias                                      └─512
# │    │    └─Conv2d: 3-39                 [1, 512, 7, 7]            (1,179,648)
# │    │    │    └─weight                                            └─1,179,648
# │    │    └─BatchNorm2d: 3-40            [1, 512, 7, 7]            (1,024)
# │    │    │    └─weight                                            ├─512
# │    │    │    └─bias                                              └─512
# │    │    └─ReLU: 3-41                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-42                 [1, 512, 7, 7]            (2,359,296)
# │    │    │    └─weight                                            └─2,359,296
# │    │    └─BatchNorm2d: 3-43            [1, 512, 7, 7]            (1,024)
# │    │    │    └─weight                                            ├─512
# │    │    │    └─bias                                              └─512
# │    │    └─Sequential: 3-44             [1, 512, 7, 7]            (132,096)
# │    │    │    └─0.weight                                          ├─131,072
# │    │    │    └─1.weight                                          ├─512
# │    │    │    └─1.bias                                            └─512
# │    │    └─ReLU: 3-45                   [1, 512, 7, 7]            --
# │    └─BasicBlock: 2-8                   [1, 512, 7, 7]            --
# │    │    └─conv1.weight                                           ├─2,359,296
# │    │    └─bn1.weight                                             ├─512
# │    │    └─bn1.bias                                               ├─512
# │    │    └─conv2.weight                                           ├─2,359,296
# │    │    └─bn2.weight                                             ├─512
# │    │    └─bn2.bias                                               └─512
# │    │    └─Conv2d: 3-46                 [1, 512, 7, 7]            (2,359,296)
# │    │    │    └─weight                                            └─2,359,296
# │    │    └─BatchNorm2d: 3-47            [1, 512, 7, 7]            (1,024)
# │    │    │    └─weight                                            ├─512
# │    │    │    └─bias                                              └─512
# │    │    └─ReLU: 3-48                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-49                 [1, 512, 7, 7]            (2,359,296)
# │    │    │    └─weight                                            └─2,359,296
# │    │    └─BatchNorm2d: 3-50            [1, 512, 7, 7]            (1,024)
# │    │    │    └─weight                                            ├─512
# │    │    │    └─bias                                              └─512
# │    │    └─ReLU: 3-51                   [1, 512, 7, 7]            --
# ├─AdaptiveAvgPool2d: 1-9                 [1, 512, 1, 1]            --
# ├─Linear: 1-10                           [1, 50]                   25,650
# │    └─weight                                                      ├─25,600
# │    └─bias                                                        └─50
# ==========================================================================================
# Total params: 11,202,162
# Trainable params: 25,650
# Non-trainable params: 11,176,512
# Total mult-adds (G): 1.81
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 39.74
# Params size (MB): 44.81
# Estimated Total Size (MB): 85.15
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNet                                   [1, 50]                   --
# ├─Conv2d: 1-1                            [1, 64, 112, 112]         (9,408)
# │    └─weight                                                      └─9,408
# ├─BatchNorm2d: 1-2                       [1, 64, 112, 112]         (128)
# │    └─weight                                                      ├─64
# │    └─bias                                                        └─64
# ├─ReLU: 1-3                              [1, 64, 112, 112]         --
# ├─MaxPool2d: 1-4                         [1, 64, 56, 56]           --
# ├─Sequential: 1-5                        [1, 64, 56, 56]           --
# │    └─0.conv1.weight                                              ├─36,864
# │    └─0.bn1.weight                                                ├─64
# │    └─0.bn1.bias                                                  ├─64
# │    └─0.conv2.weight                                              ├─36,864
# │    └─0.bn2.weight                                                ├─64
# │    └─0.bn2.bias                                                  ├─64
# │    └─1.conv1.weight                                              ├─36,864
# │    └─1.bn1.weight                                                ├─64
# │    └─1.bn1.bias                                                  ├─64
# │    └─1.conv2.weight                                              ├─36,864
# │    └─1.bn2.weight                                                ├─64
# │    └─1.bn2.bias                                                  └─64
# │    └─BasicBlock: 2-1                   [1, 64, 56, 56]           --
# │    │    └─conv1.weight                                           ├─36,864
# │    │    └─bn1.weight                                             ├─64
# │    │    └─bn1.bias                                               ├─64
# │    │    └─conv2.weight                                           ├─36,864
# │    │    └─bn2.weight                                             ├─64
# │    │    └─bn2.bias                                               └─64
# │    │    └─Conv2d: 3-1                  [1, 64, 56, 56]           (36,864)
# │    │    │    └─weight                                            └─36,864
# │    │    └─BatchNorm2d: 3-2             [1, 64, 56, 56]           (128)
# │    │    │    └─weight                                            ├─64
# │    │    │    └─bias                                              └─64
# │    │    └─ReLU: 3-3                    [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-4                  [1, 64, 56, 56]           (36,864)
# │    │    │    └─weight                                            └─36,864
# │    │    └─BatchNorm2d: 3-5             [1, 64, 56, 56]           (128)
# │    │    │    └─weight                                            ├─64
# │    │    │    └─bias                                              └─64
# │    │    └─ReLU: 3-6                    [1, 64, 56, 56]           --
# │    └─BasicBlock: 2-2                   [1, 64, 56, 56]           --
# │    │    └─conv1.weight                                           ├─36,864
# │    │    └─bn1.weight                                             ├─64
# │    │    └─bn1.bias                                               ├─64
# │    │    └─conv2.weight                                           ├─36,864
# │    │    └─bn2.weight                                             ├─64
# │    │    └─bn2.bias                                               └─64
# │    │    └─Conv2d: 3-7                  [1, 64, 56, 56]           (36,864)
# │    │    │    └─weight                                            └─36,864
# │    │    └─BatchNorm2d: 3-8             [1, 64, 56, 56]           (128)
# │    │    │    └─weight                                            ├─64
# │    │    │    └─bias                                              └─64
# │    │    └─ReLU: 3-9                    [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-10                 [1, 64, 56, 56]           (36,864)
# │    │    │    └─weight                                            └─36,864
# │    │    └─BatchNorm2d: 3-11            [1, 64, 56, 56]           (128)
# │    │    │    └─weight                                            ├─64
# │    │    │    └─bias                                              └─64
# │    │    └─ReLU: 3-12                   [1, 64, 56, 56]           --
# ├─Sequential: 1-6                        [1, 128, 28, 28]          --
# │    └─0.conv1.weight                                              ├─73,728
# │    └─0.bn1.weight                                                ├─128
# │    └─0.bn1.bias                                                  ├─128
# │    └─0.conv2.weight                                              ├─147,456
# │    └─0.bn2.weight                                                ├─128
# │    └─0.bn2.bias                                                  ├─128
# │    └─0.downsample.0.weight                                       ├─8,192
# │    └─0.downsample.1.weight                                       ├─128
# │    └─0.downsample.1.bias                                         ├─128
# │    └─1.conv1.weight                                              ├─147,456
# │    └─1.bn1.weight                                                ├─128
# │    └─1.bn1.bias                                                  ├─128
# │    └─1.conv2.weight                                              ├─147,456
# │    └─1.bn2.weight                                                ├─128
# │    └─1.bn2.bias                                                  └─128
# │    └─BasicBlock: 2-3                   [1, 128, 28, 28]          --
# │    │    └─conv1.weight                                           ├─73,728
# │    │    └─bn1.weight                                             ├─128
# │    │    └─bn1.bias                                               ├─128
# │    │    └─conv2.weight                                           ├─147,456
# │    │    └─bn2.weight                                             ├─128
# │    │    └─bn2.bias                                               ├─128
# │    │    └─downsample.0.weight                                    ├─8,192
# │    │    └─downsample.1.weight                                    ├─128
# │    │    └─downsample.1.bias                                      └─128
# │    │    └─Conv2d: 3-13                 [1, 128, 28, 28]          (73,728)
# │    │    │    └─weight                                            └─73,728
# │    │    └─BatchNorm2d: 3-14            [1, 128, 28, 28]          (256)
# │    │    │    └─weight                                            ├─128
# │    │    │    └─bias                                              └─128
# │    │    └─ReLU: 3-15                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-16                 [1, 128, 28, 28]          (147,456)
# │    │    │    └─weight                                            └─147,456
# │    │    └─BatchNorm2d: 3-17            [1, 128, 28, 28]          (256)
# │    │    │    └─weight                                            ├─128
# │    │    │    └─bias                                              └─128
# │    │    └─Sequential: 3-18             [1, 128, 28, 28]          (8,448)
# │    │    │    └─0.weight                                          ├─8,192
# │    │    │    └─1.weight                                          ├─128
# │    │    │    └─1.bias                                            └─128
# │    │    └─ReLU: 3-19                   [1, 128, 28, 28]          --
# │    └─BasicBlock: 2-4                   [1, 128, 28, 28]          --
# │    │    └─conv1.weight                                           ├─147,456
# │    │    └─bn1.weight                                             ├─128
# │    │    └─bn1.bias                                               ├─128
# │    │    └─conv2.weight                                           ├─147,456
# │    │    └─bn2.weight                                             ├─128
# │    │    └─bn2.bias                                               └─128
# │    │    └─Conv2d: 3-20                 [1, 128, 28, 28]          (147,456)
# │    │    │    └─weight                                            └─147,456
# │    │    └─BatchNorm2d: 3-21            [1, 128, 28, 28]          (256)
# │    │    │    └─weight                                            ├─128
# │    │    │    └─bias                                              └─128
# │    │    └─ReLU: 3-22                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-23                 [1, 128, 28, 28]          (147,456)
# │    │    │    └─weight                                            └─147,456
# │    │    └─BatchNorm2d: 3-24            [1, 128, 28, 28]          (256)
# │    │    │    └─weight                                            ├─128
# │    │    │    └─bias                                              └─128
# │    │    └─ReLU: 3-25                   [1, 128, 28, 28]          --
# ├─Sequential: 1-7                        [1, 256, 14, 14]          --
# │    └─0.conv1.weight                                              ├─294,912
# │    └─0.bn1.weight                                                ├─256
# │    └─0.bn1.bias                                                  ├─256
# │    └─0.conv2.weight                                              ├─589,824
# │    └─0.bn2.weight                                                ├─256
# │    └─0.bn2.bias                                                  ├─256
# │    └─0.downsample.0.weight                                       ├─32,768
# │    └─0.downsample.1.weight                                       ├─256
# │    └─0.downsample.1.bias                                         ├─256
# │    └─1.conv1.weight                                              ├─589,824
# │    └─1.bn1.weight                                                ├─256
# │    └─1.bn1.bias                                                  ├─256
# │    └─1.conv2.weight                                              ├─589,824
# │    └─1.bn2.weight                                                ├─256
# │    └─1.bn2.bias                                                  └─256
# │    └─BasicBlock: 2-5                   [1, 256, 14, 14]          --
# │    │    └─conv1.weight                                           ├─294,912
# │    │    └─bn1.weight                                             ├─256
# │    │    └─bn1.bias                                               ├─256
# │    │    └─conv2.weight                                           ├─589,824
# │    │    └─bn2.weight                                             ├─256
# │    │    └─bn2.bias                                               ├─256
# │    │    └─downsample.0.weight                                    ├─32,768
# │    │    └─downsample.1.weight                                    ├─256
# │    │    └─downsample.1.bias                                      └─256
# │    │    └─Conv2d: 3-26                 [1, 256, 14, 14]          (294,912)
# │    │    │    └─weight                                            └─294,912
# │    │    └─BatchNorm2d: 3-27            [1, 256, 14, 14]          (512)
# │    │    │    └─weight                                            ├─256
# │    │    │    └─bias                                              └─256
# │    │    └─ReLU: 3-28                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-29                 [1, 256, 14, 14]          (589,824)
# │    │    │    └─weight                                            └─589,824
# │    │    └─BatchNorm2d: 3-30            [1, 256, 14, 14]          (512)
# │    │    │    └─weight                                            ├─256
# │    │    │    └─bias                                              └─256
# │    │    └─Sequential: 3-31             [1, 256, 14, 14]          (33,280)
# │    │    │    └─0.weight                                          ├─32,768
# │    │    │    └─1.weight                                          ├─256
# │    │    │    └─1.bias                                            └─256
# │    │    └─ReLU: 3-32                   [1, 256, 14, 14]          --
# │    └─BasicBlock: 2-6                   [1, 256, 14, 14]          --
# │    │    └─conv1.weight                                           ├─589,824
# │    │    └─bn1.weight                                             ├─256
# │    │    └─bn1.bias                                               ├─256
# │    │    └─conv2.weight                                           ├─589,824
# │    │    └─bn2.weight                                             ├─256
# │    │    └─bn2.bias                                               └─256
# │    │    └─Conv2d: 3-33                 [1, 256, 14, 14]          (589,824)
# │    │    │    └─weight                                            └─589,824
# │    │    └─BatchNorm2d: 3-34            [1, 256, 14, 14]          (512)
# │    │    │    └─weight                                            ├─256
# │    │    │    └─bias                                              └─256
# │    │    └─ReLU: 3-35                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-36                 [1, 256, 14, 14]          (589,824)
# │    │    │    └─weight                                            └─589,824
# │    │    └─BatchNorm2d: 3-37            [1, 256, 14, 14]          (512)
# │    │    │    └─weight                                            ├─256
# │    │    │    └─bias                                              └─256
# │    │    └─ReLU: 3-38                   [1, 256, 14, 14]          --
# ├─Sequential: 1-8                        [1, 512, 7, 7]            --
# │    └─0.conv1.weight                                              ├─1,179,648
# │    └─0.bn1.weight                                                ├─512
# │    └─0.bn1.bias                                                  ├─512
# │    └─0.conv2.weight                                              ├─2,359,296
# │    └─0.bn2.weight                                                ├─512
# │    └─0.bn2.bias                                                  ├─512
# │    └─0.downsample.0.weight                                       ├─131,072
# │    └─0.downsample.1.weight                                       ├─512
# │    └─0.downsample.1.bias                                         ├─512
# │    └─1.conv1.weight                                              ├─2,359,296
# │    └─1.bn1.weight                                                ├─512
# │    └─1.bn1.bias                                                  ├─512
# │    └─1.conv2.weight                                              ├─2,359,296
# │    └─1.bn2.weight                                                ├─512
# │    └─1.bn2.bias                                                  └─512
# │    └─BasicBlock: 2-7                   [1, 512, 7, 7]            --
# │    │    └─conv1.weight                                           ├─1,179,648
# │    │    └─bn1.weight                                             ├─512
# │    │    └─bn1.bias                                               ├─512
# │    │    └─conv2.weight                                           ├─2,359,296
# │    │    └─bn2.weight                                             ├─512
# │    │    └─bn2.bias                                               ├─512
# │    │    └─downsample.0.weight                                    ├─131,072
# │    │    └─downsample.1.weight                                    ├─512
# │    │    └─downsample.1.bias                                      └─512
# │    │    └─Conv2d: 3-39                 [1, 512, 7, 7]            (1,179,648)
# │    │    │    └─weight                                            └─1,179,648
# │    │    └─BatchNorm2d: 3-40            [1, 512, 7, 7]            (1,024)
# │    │    │    └─weight                                            ├─512
# │    │    │    └─bias                                              └─512
# │    │    └─ReLU: 3-41                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-42                 [1, 512, 7, 7]            (2,359,296)
# │    │    │    └─weight                                            └─2,359,296
# │    │    └─BatchNorm2d: 3-43            [1, 512, 7, 7]            (1,024)
# │    │    │    └─weight                                            ├─512
# │    │    │    └─bias                                              └─512
# │    │    └─Sequential: 3-44             [1, 512, 7, 7]            (132,096)
# │    │    │    └─0.weight                                          ├─131,072
# │    │    │    └─1.weight                                          ├─512
# │    │    │    └─1.bias                                            └─512
# │    │    └─ReLU: 3-45                   [1, 512, 7, 7]            --
# │    └─BasicBlock: 2-8                   [1, 512, 7, 7]            --
# │    │    └─conv1.weight                                           ├─2,359,296
# │    │    └─bn1.weight                                             ├─512
# │    │    └─bn1.bias                                               ├─512
# │    │    └─conv2.weight                                           ├─2,359,296
# │    │    └─bn2.weight                                             ├─512
# │    │    └─bn2.bias                                               └─512
# │    │    └─Conv2d: 3-46                 [1, 512, 7, 7]            (2,359,296)
# │    │    │    └─weight                                            └─2,359,296
# │    │    └─BatchNorm2d: 3-47            [1, 512, 7, 7]            (1,024)
# │    │    │    └─weight                                            ├─512
# │    │    │    └─bias                                              └─512
# │    │    └─ReLU: 3-48                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-49                 [1, 512, 7, 7]            (2,359,296)
# │    │    │    └─weight                                            └─2,359,296
# │    │    └─BatchNorm2d: 3-50            [1, 512, 7, 7]            (1,024)
# │    │    │    └─weight                                            ├─512
# │    │    │    └─bias                                              └─512
# │    │    └─ReLU: 3-51                   [1, 512, 7, 7]            --
# ├─AdaptiveAvgPool2d: 1-9                 [1, 512, 1, 1]            --
# ├─Linear: 1-10                           [1, 50]                   25,650
# │    └─weight                                                      ├─25,600
# │    └─bias                                                        └─50
# ==========================================================================================
# Total params: 11,202,162
# Trainable params: 25,650
# Non-trainable params: 11,176,512
# Total mult-adds (G): 1.81
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 39.74
# Params size (MB): 44.81
# Estimated Total Size (MB): 85.15
# ==========================================================================================

# %% [markdown]
# <img src="static_images/icons/noun-question-mark-869751.png" alt="?" style="width:25px"/> __Question:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# <img src="static_images/icons/noun-answer-3361020.png" alt=">" style="width:25px"/>  __Answer:__ I decided to use ResNet18 for the base of my model, since it performs fairly well on ImageNet and is not too large of a model. Also, since ResNet18 was trained for the ImageNet task, it is a good model to use for this landmark classificaiton task, since both ImageNet and this landmark task use images of natural scenes.

# %% [markdown]
# Now play with the hyperparameters and see which performance you can get on the validation set. You should get at least 60% for a passing grade, but a good model choice and a good training strategy could get you up to 80% or so. Let's see how close you can get!

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 3: Test the Model
#
# Try out your model on the test dataset of landmark images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60% and matches more or less what you got on the validation set (otherwise you're overfitting!)

# %%
import torch
from src.train import one_epoch_test
from src.transfer import get_model_transfer_learning

model_transfer = get_model_transfer_learning("resnet18", n_classes=num_classes)
# Load saved weights
model_transfer.load_state_dict(torch.load('checkpoints/model_transfer.pt'))

one_epoch_test(data_loaders['test'], model_transfer, loss)
# Out:
# Testing: 100%|██████████████████████████████████| 10/10 [00:05<00:00,  1.82it/s]
# Test Loss: 2.868267
#
#
# Test Accuracy: 37% (470/1250)

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 4: Export using torchscript
#
# Now, just like we did with our original model, we export the best fit model using torchscript so that it can be used in our application:

# %%
from src.predictor import Predictor
from src.helpers import compute_mean_and_std

# First let's get the class names from our data loaders
class_names = data_loaders["train"].dataset.classes

# Then let's move the model_transfer to the CPU
# (we don't need GPU for inference)
model_transfer = model_transfer.cpu()
# Let's make sure we use the right weights by loading the
# best weights we have found during training
# NOTE: remember to use map_location='cpu' so the weights
# are loaded on the CPU (and not the GPU)
model_transfer.load_state_dict(
    torch.load("checkpoints/model_transfer.pt", map_location="cpu")
)

# Let's wrap our model using the predictor class
mean, std = compute_mean_and_std()
predictor = Predictor(model_transfer, class_names, mean, std).cpu()

# Export using torch.jit.script
scripted_predictor = torch.jit.script(predictor)
scripted_predictor.save("checkpoints/transfer_exported.pt")
# Out:
# Reusing cached mean and std for landmark_images

# %%
import torch
import warnings
from src.predictor import predictor_test
from src.helpers import plot_confusion_matrix

model_reloaded = torch.jit.load("checkpoints/transfer_exported.pt")

warnings.filterwarnings("ignore") # Disable warnings
pred, truth = predictor_test(data_loaders['test'], model_reloaded)
warnings.filterwarnings("default") # Re-enable warnings

plot_confusion_matrix(pred, truth)
